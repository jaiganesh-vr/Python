# %%
import pandas as pd

# %%
df = pd.DataFrame(
    {
        "Name":["Jaiganesh","Balasubramaniyan","Srinivasan",],
        "Age" :[27,42,32],
        "Sex" :["Male","Male","Male"],
    }
)
print(df)
print(df["Age"])
# Out:
#                Name  Age   Sex
# 0         Jaiganesh   27  Male
# 1  Balasubramaniyan   42  Male
# 2        Srinivasan   32  Male
# 0    27
# 1    42
# 2    32
# Name: Age, dtype: int64

# %%
df = pd.Series([11,12,13], name = "Age")
print(df.describe())
# Out:
# count     3.0
# mean     12.0
# std       1.0
# min      11.0
# 25%      11.5
# 50%      12.0
# 75%      12.5
# max      13.0
# Name: Age, dtype: float64

# %%
titanic = pd.read_csv("Data/titanic.csv")
print(titanic.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
print(titanic.head(10))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
print(titanic.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
print(titanic.shape)
# Out:
# (891, 12)

# %%
ages = titanic["Age"]
df = titanic["Age"]>35
count=0
for i in df:
    if i == True:
        count+=1
print(count)
# Out:
# 217

# %%
adult_names = titanic.loc[titanic["Age"]>35,"Name"]
print(adult_names.shape)
for i in adult_names:
    print(i)
# Out:
# (217,)
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)
# McCarthy, Mr. Timothy J
# Bonnell, Miss. Elizabeth
# Andersson, Mr. Anders Johan
# Hewlett, Mrs. (Mary D Kingcome)
# Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)
# Uruchurtu, Don. Manuel E
# Wheadon, Mr. Edward H
# Holverson, Mr. Alexander Oskar
# Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# Harper, Mrs. Henry Sleeper (Myna Haxtun)
# Ostby, Mr. Engelhart Cornelius
# Icard, Miss. Amelie
# Harris, Mr. Henry Birkhardt
# Chaffee, Mr. Herbert Fuller
# Coxon, Mr. Daniel
# Goldschmidt, Mr. George B
# Gustafsson, Mr. Anders Vilhelm
# Rekic, Mr. Tido
# Porter, Mr. Walter Chamberlain
# Connors, Mr. Patrick
# White, Mr. Percival Wayland
# Ekstrom, Mr. Johan
# Robins, Mrs. Alexander A (Grace Charity Laury)
# Futrelle, Mr. Jacques Heath
# Navratil, Mr. Michel ("Louis M Hoffman")
# Byles, Rev. Thomas Roussel Davids
# Bateman, Rev. Robert James
# Meo, Mr. Alfonzo
# van Billiard, Mr. Austin Blyler
# ...

# %%
subset = titanic.iloc[9:25,4]

titanic.iloc[:,4] = "female"
print(titanic.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris  female  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry  female  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
subset = titanic.loc[titanic["Age"]>55]
print(subset.shape)
# Out:
# (40, 12)

# %%
df = titanic.sort_values(by="Age")

# %%
df = pd.concat([titanic,titanic])
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1782 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1782 non-null   int64
#  1   Survived     1782 non-null   int64
#  2   Pclass       1782 non-null   int64
#  3   Name         1782 non-null   object
#  4   Sex          1782 non-null   object
#  5   Age          1428 non-null   float64
#  6   SibSp        1782 non-null   int64
#  7   Parch        1782 non-null   int64
#  8   Ticket       1782 non-null   object
#  9   Fare         1782 non-null   float64
#  10  Cabin        408 non-null    object
#  11  Embarked     1782 non-null   object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 181.0+ KB
# None

# %%
df = pd.merge(titanic,titanic)
print(df.shape)
# Out:
# (891, 12)

# %%
df = pd.DataFrame(
    {
        "Name":["Jaiganesh","Balasubramaniyan","Srinivasan",],
        "Age" :[27,42,32],
        "Sex" :["Male","Male","Male"],
    }
)

df2 = df[df["Name"]=="Jaiganesh"]
print(df2.shape)
# Out:
# (1, 3)
